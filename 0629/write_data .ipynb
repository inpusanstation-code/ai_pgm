# %%
import os 
# newfile2.py

os.makedirs("C://doit", exist_ok=True)
f = open("C://doit//새파일.txt", 'w')
for i in range(1, 11):
    data=f"%d번째 줄입니다.\n"
    f.write(data)
f.close()

# %%
# sys1.py
import sys
args = sys.argv[1:] # 명령행 인수
for i in args:
    print(i)
